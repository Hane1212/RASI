# %% [markdown]
# This dataset focuses on air quality assessment across various regions. The dataset contains 5000 samples and captures critical environmental and demographic factors that influence pollution levels.
# Data elements:
# - Temperature (°C): Average temperature of the region.
# - Humidity (%): Relative humidity recorded in the region.
# - PM2.5 Concentration (µg/m³): Fine particulate matter levels.
# - PM10 Concentration (µg/m³): Coarse particulate matter levels.
# - NO2 Concentration (ppb): Nitrogen dioxide levels.
# - SO2 Concentration (ppb): Sulfur dioxide levels.
# - CO Concentration (ppm): Carbon monoxide levels.
# - Proximity to Industrial Areas (km): Distance to the nearest industrial zone.
# - Population Density (people/km²): Number of people per square kilometer in the region.
#
# Target Variable: Air Quality Levels
# - Good: Clean air with low pollution levels.
# - Moderate: Acceptable air quality but with some pollutants present.
# - Poor: Noticeable pollution that may cause health issues for sensitive groups.
# - Hazardous: Highly polluted air posing serious health risks to the population.
#
# Min value and Max value foreach factor
# | #  | Parameter                         | Min Value  | Max Value |
# |----|------------------------------------|-----------|-----------|
# | 1  | Temperature (°C)                   | -89.2     | 56.7      |
# | 2  | Humidity (%)                       | 0         | 100       |
# | 3  | PM2.5 (µg/m³)                      | 0         | 500       |
# | 4  | PM10 (µg/m³)                       | 0         | 600       |
# | 5  | NO2 (ppb)                          | 0         | 300       |
# | 6  | SO2 (ppb)                          | 0         | 500       |
# | 7  | CO (ppm)                           | 0         | 50        |
# | 8  | Proximity to Industrial Areas      | 0         | 100       |
# | 9  | Population Density (people/km²)    | 1         | 50,000    |

# %% [markdown]
# The issue from this data set.
# 1. A required feature (column) is missing
#    - Example: The dataset is missing the **"Population Density (people/km²)"** column, which is essential for air quality analysis.
#    - Sample: test_001_missing_column.csv
# 2. Missing values in a required column:
#    - Example: The **"PM2.5"** column contains empty or `NaN` values, making it unusable for analysis.
#    - Sample: test_002_missing_value.csv
# 3. Unknown values for a given feature
#    - Example: The column contains the value `"???"`, which is not a valid category.
#    - Sample: test_003_unknow_value.csv
#
# 4. Wrong value for a given feature of:
# Current value of raw data:
# | #  | Parameter                         | Min Value | Max Value|
# |----|------------------------------------|----------|----------|
# | 1  | Temperature (°C)                   | 13.4     | 58.6     |
# | 2  | Humidity (%)                       | 36       | 128.1    |
# | 3  | PM2.5 (µg/m³)                      | 0        | 295      |
# | 4  | PM10 (µg/m³)                       | -0.2     | 315.8    |
# | 5  | NO2 (ppb)                          | 7.4      | 64.9     |
# | 6  | SO2 (ppb)                          | -6.2     | 44.9     |
# | 7  | CO (ppm)                           | 0.65     | 3.72     |
# | 8  | Proximity to Industrial Areas      | 2.5      | 25.8     |
# | 9  | Population Density (people/km²)    | 188      | 957      |
#
#    - Humidity (%) : value >100*C
#    - PM10 (µg/m³) : value <0
#    - SO2 (ppb)    : value <0
#
# 5. A string value in a numerical column
#    - Example: The **"NO2 (ppb)"** column contains `"High"` instead of a numerical value.
#    - Sample: test_005_string_value_in_number.csv
#
# 6. Duplicate rows in the dataset
#    - Example: Identical rows appear multiple times, skewing analysis.
#    - Sample: test_006_duplicate_rows.csv
#
# 7. Outliers and Extreme Values
#    - Example: The value of **"Proximity to Industrial Areas"** is too high >500km, 10000km
#    - Sample: test_007_outliers_extreme_value.csv
